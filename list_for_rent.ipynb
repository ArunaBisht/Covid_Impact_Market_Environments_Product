# %%
# Initial imports
import os
import requests
import pandas as pd
from dotenv import load_dotenv
import datetime

# %matplotlib inline

# %%
# Load .env environment variables
load_dotenv()
# Out:
# True

# %%
# Set Realtor API key 
api_key = os.getenv("RAPID_API_KEY")

# %%
url = "https://realtor.p.rapidapi.com/properties/v2/list-for-rent"

querystring = {"state_code":"CA","prop_type":"single_family,multi_family,condo","sort":"sold_date","offset":"0"}

headers = {
    'x-rapidapi-key': api_key,
    'x-rapidapi-host': "realtor.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

# %%
# Convert JSON string to a dictionary
real_estate_data = response.json()

# %%
# Create Dataframe 
re_df = real_estate_data['properties']

real_estate_df = pd.json_normalize(re_df)[['prop_type', 'list_date','last_update', 'prop_status', 'year_built', 'address.city', 'address.county','address.postal_code','address.lat','address.lon','community.price_min', 'community.baths_min', 'community.beds_min', 'community.sqft_min']]
real_estate_df.to_csv('list_for_rent_data.csv')
real_estate_df
# Out:
#          prop_type                 list_date               last_update  \
# 0            condo  2021-02-15T14:43:00.000Z   2021-02-15T14:55:14.73Z
# 1    single_family  2021-02-15T16:43:00.000Z   2021-02-15T16:55:13.13Z
# 2            condo  2021-02-15T16:43:00.000Z   2021-02-15T16:55:13.13Z
# 3    single_family  2021-01-18T16:43:00.000Z   2021-02-15T14:55:14.73Z
# 4    single_family  2021-02-15T14:43:00.000Z   2021-02-15T14:55:14.73Z
# ..             ...                       ...                       ...
# 195          condo                       NaN  2021-02-15T04:55:16.953Z
# 196          condo                       NaN  2021-02-15T04:55:16.953Z
# 197          condo                       NaN  2021-02-15T04:55:16.953Z
# 198  single_family                       NaN  2021-02-15T04:55:16.953Z
# 199          condo                       NaN  2021-02-15T04:55:16.953Z
#
#     prop_status  year_built   address.city address.county address.postal_code  \
# ...
