# %%
# Initial imports
import os
import requests
import pandas as pd
from dotenv import load_dotenv
import datetime

# %matplotlib inline

# %%
# Load .env environment variables
load_dotenv()
# Out:
# True

# %%
# Set Realtor API key 
api_key = os.getenv("RAPID_API_KEY")

# %%
url = "https://realtor.p.rapidapi.com/properties/v2/list-for-sale"

querystring = {"state_code":"CA","prop_type":"single_family,multi_family,condo","sort":"newest","offset":"0"}

headers = {
    'x-rapidapi-key': api_key,
    'x-rapidapi-host': "realtor.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

# %%
# Convert JSON string to a dictionary
real_estate_data = response.json()

# %%
# Create Dataframe 
re_df = real_estate_data['properties']

real_estate_df = pd.json_normalize(re_df)[['prop_type','last_update', 'prop_status', 'address.city', 'address.county','address.postal_code','address.lat','address.lon','price']]
# real_estate_df.to_csv('list_for_sale_data.csv')
real_estate_df
# Out:
#          prop_type           last_update prop_status      address.city  \
# 0            condo  2021-02-15T17:12:37Z    for_sale              Bell
# 1    single_family  2021-02-15T17:12:37Z    for_sale            Orange
# 2            condo  2021-02-15T17:12:37Z    for_sale  Hawaiian Gardens
# 3    single_family  2021-02-15T19:14:33Z    for_sale            Eureka
# 4            condo  2021-02-15T17:12:19Z    for_sale    Woodland Hills
# ..             ...                   ...         ...               ...
# 195  single_family  2021-02-15T14:21:41Z    for_sale           Atwater
# 196  single_family  2021-02-15T14:25:12Z    for_sale           Atwater
# 197  single_family  2021-02-15T14:21:58Z    for_sale        Sacramento
# 198  single_family  2021-02-15T18:17:36Z    for_sale           Menifee
# 199  single_family  2021-02-15T15:03:37Z    for_sale         Daly City
#
#     address.county address.postal_code  address.lat  address.lon     price
# ...
