# %%
# Initial imports
import os
import requests
import pandas as pd
from dotenv import load_dotenv
import datetime

# %matplotlib inline

# %%
# Load .env environment variables
load_dotenv()
# Out:
# True

# %%
# Set Realtor API key 
api_key = os.getenv("RAPID_API_KEY")

# %%
url = "https://realtor.p.rapidapi.com/properties/v2/list-sold"

querystring = {"state_code":"CA","prop_type":"single_family,multi_family,condo","sort":"sold_date","offset":"0"}

headers = {
    'x-rapidapi-key': api_key,
    'x-rapidapi-host': "realtor.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
# Out:
# <Response [200]>

# %%
limit = 200
ret = []
for x in range(50):
    querystring = {"state_code":"CA","prop_type":"single_family,multi_family,condo","sort":"sold_date","offset":x*limit}
    response = requests.request("GET", url, headers=headers, params=querystring)
    real_estate_data = response.json()
    re_df = real_estate_data['properties']
    ret.append(re_df)

# %%
ret[9]
ret2 = []
for x in ret:
    ret2 = ret2 + x

# %%
len(ret2)
real_estate_df = pd.json_normalize(ret2)[['prop_type', 'list_date','last_update', 'prop_status', 'year_built', 'address.city', 'address.county','address.postal_code','address.lat','address.lon','price', 'baths_full', 'baths_half', 'beds', 'building_size.size']]
# real_estate_df.to_csv('sold_data.csv')
real_estate_df
# Out:
#           prop_type             list_date           last_update   prop_status  \
# 0     single_family  2021-01-07T00:54:03Z  2021-02-16T13:08:05Z  not_for_sale
# 1             condo  2020-12-31T03:24:50Z  2021-02-16T10:33:02Z  not_for_sale
# 2     single_family  2021-01-20T02:45:45Z  2021-02-16T10:53:58Z  not_for_sale
# 3     single_family  2020-04-03T23:21:35Z  2021-02-16T10:42:26Z  not_for_sale
# 4     single_family  2020-06-16T18:48:38Z  2021-02-16T10:43:17Z  not_for_sale
# ...             ...                   ...                   ...           ...
# 1995  single_family  2020-11-10T05:24:28Z  2021-02-11T12:52:45Z  not_for_sale
# 1996          condo  2020-12-29T13:14:02Z  2021-02-11T12:17:27Z  not_for_sale
# 1997          condo  2020-12-08T17:15:12Z  2021-02-13T14:08:06Z  not_for_sale
# 1998          condo  2020-12-17T20:23:51Z  2021-02-13T22:39:59Z  not_for_sale
# 1999  single_family  2021-01-06T08:09:37Z  2021-02-11T12:01:58Z  not_for_sale
#
#       year_built          address.city address.county address.postal_code  \
# 0         1988.0                Novato          Marin               94945
# 1         1968.0            Long Beach    Los Angeles               90814
# 2         1953.0                Orange         Orange               92866
# 3         1992.0             Los Gatos     Santa Cruz               95033
# 4         1965.0          Palm Springs      Riverside               92262
# ...          ...                   ...            ...                 ...
# 1995      1983.0              Palmdale    Los Angeles               93550
# 1996      1973.0  Palos Verdes Estates    Los Angeles               90274
# 1997      1964.0                Tustin         Orange               92780
# 1998      1978.0               Del Mar      San Diego               92014
# 1999      1987.0              Petaluma         Sonoma               94954
#
#       address.lat  address.lon    price  baths_full  baths_half  beds  \
# 0       38.120453  -122.521232  1417000         2.0         1.0   4.0
# 1       33.768341  -118.144883   545000         2.0         NaN   2.0
# 2       33.794516  -117.845798  1215000         3.0         NaN   3.0
# 3       37.115316  -121.965266   750000         1.0         NaN   2.0
# 4       33.842382  -116.555988  2150000         4.0         NaN   3.0
# ...           ...          ...      ...         ...         ...   ...
# 1995    34.557070  -118.082708   295000         2.0         NaN   3.0
# 1996    33.774600  -118.416456   780000         2.0         NaN   2.0
# 1997    33.734700  -117.831338   400000         2.0         NaN   2.0
# 1998    32.948534  -117.245297   600000         2.0         NaN   2.0
# 1999    38.264038  -122.650615   775000         2.0         NaN   3.0
#
#       building_size.size
# 0                 3561.0
# 1                 1115.0
# 2                 1862.0
# 3                 1428.0
# 4                 3057.0
# ...                  ...
# 1995              1190.0
# 1996              1166.0
# 1997               997.0
# 1998              1164.0
# 1999              1348.0
#
# [2000 rows x 15 columns]
